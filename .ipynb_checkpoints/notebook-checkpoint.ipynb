# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

# %matplotlib inline

# %%
df = pd.read_csv('data/TMDB_tv_dataset_v3.csv')

# %%
df.head()
# Out:
#       id              name  number_of_seasons  number_of_episodes  \
# 0   1399   Game of Thrones                  8                  73
# 1  71446       Money Heist                  3                  41
# 2  66732   Stranger Things                  4                  34
# 3   1402  The Walking Dead                 11                 177
# 4  63174           Lucifer                  6                  93
#
#   original_language  vote_count  vote_average  \
# 0                en       21857         8.442
# 1                es       17836         8.257
# 2                en       16161         8.624
# 3                en       15432         8.121
# 4                en       13870         8.486
#
#                                             overview  adult  \
# 0  Seven noble families fight for control of the ...  False
# 1  To carry out the biggest heist in history, a m...  False
# 2  When a young boy vanishes, a small town uncove...  False
# 3  Sheriff's deputy Rick Grimes awakens from a co...  False
# 4  Bored and unhappy as the Lord of Hell, Lucifer...  False
#
#                       backdrop_path  ...                           tagline  \
# 0   /2OMB0ynKlyIenMJWI2Dy9IWT4c.jpg  ...                  Winter Is Coming
# 1  /gFZriCkpJYsApPZEF3jhxL4yLzG.jpg  ...              The perfect robbery.
# 2  /2MaumbgBlW1NoPo3ZJO38A6v7OS.jpg  ...     Every ending has a beginning.
# 3  /x4salpjB11umlUOltfNvSSrjSXm.jpg  ...  Fight the dead. Fear the living.
# 4  /aDBRtunw49UF4XmqfyNuD9nlYIu.jpg  ...              It's good to be bad.
#
#                                         genres                 created_by  \
# 0  Sci-Fi & Fantasy, Drama, Action & Adventure  David Benioff, D.B. Weiss
# 1                                 Crime, Drama                  Álex Pina
# 2             Drama, Sci-Fi & Fantasy, Mystery   Matt Duffer, Ross Duffer
# 3  Action & Adventure, Drama, Sci-Fi & Fantasy             Frank Darabont
# 4                      Crime, Sci-Fi & Fantasy                Tom Kapinos
#
#    languages           networks  origin_country spoken_languages  \
# 0         en                HBO              US          English
# 1         es  Netflix, Antena 3              ES          Español
# 2         en            Netflix              US          English
# 3         en                AMC              US          English
# 4         en       FOX, Netflix              US          English
#
#                                 production_companies  \
# 0  Revolution Sun Studios, Television 360, Genera...
# 1                                    Vancouver Media
# 2  21 Laps Entertainment, Monkey Massacre Product...
# 3  AMC Studios, Circle of Confusion, Valhalla Mot...
# 4  Warner Bros. Television, DC Entertainment, Jer...
#
#                        production_countries episode_run_time
# 0  United Kingdom, United States of America                0
# 1                                     Spain               70
# 2                  United States of America                0
# 3                  United States of America               42
# 4                  United States of America               45
#
# [5 rows x 29 columns]

# %%
df.isna().sum()
# Out:
# id                           0
# name                         5
# number_of_seasons            0
# number_of_episodes           0
# original_language            0
# vote_count                   0
# vote_average                 0
# overview                 69485
# adult                        0
# backdrop_path            84597
# first_air_date           30072
# last_air_date            28041
# homepage                109564
# in_production                0
# original_name                5
# popularity                   0
# poster_path              56513
# type                         0
# status                       0
# tagline                 153794
# genres                   64289
# created_by              124095
# languages                53791
# networks                 64841
# origin_country           31014
# spoken_languages         54502
# production_companies    102297
# production_countries     85258
# episode_run_time             0
# dtype: int64

# %%
df2= df.groupby('original_language')

# %%
df2.head()
# Out:
#             id               name  number_of_seasons  number_of_episodes  \
# 0         1399    Game of Thrones                  8                  73
# 1        71446        Money Heist                  3                  41
# 2        66732    Stranger Things                  4                  34
# 3         1402   The Walking Dead                 11                 177
# 4        63174            Lucifer                  6                  93
# ...        ...                ...                ...                 ...
# 152806  106080               حنين                  1                  10
# 153631   31126   Ruos Cheat Jivit                  0                   0
# 155699  122868          The Croft                  2                  12
# 158034  107228     Las Santísimas                  1                   1
# 158797   66881  Xal Maan U Waayey                  1                  18
#
#        original_language  vote_count  vote_average  \
# 0                     en       21857         8.442
# 1                     es       17836         8.257
# 2                     en       16161         8.624
# 3                     en       15432         8.121
# 4                     en       13870         8.486
# ...                  ...         ...           ...
# 152806                av           0         0.000
# 153631                km           0         0.000
# 155699                gd           0         0.000
# 158034                la           0         0.000
# 158797                so           0         0.000
#
#                                                  overview  adult  \
# 0       Seven noble families fight for control of the ...  False
# 1       To carry out the biggest heist in history, a m...  False
# 2       When a young boy vanishes, a small town uncove...  False
# 3       Sheriff's deputy Rick Grimes awakens from a co...  False
# 4       Bored and unhappy as the Lord of Hell, Lucifer...  False
# ...                                                   ...    ...
# 152806                                                NaN  False
# 153631  Ruos Chea Jivit is the first-ever Khmer film t...  False
# 155699  Documentary following Donald MacSween as he tr...  False
# 158034  Five close friends will make us live different...  False
# 158797                                                NaN  False
#
#                            backdrop_path  ...  \
# 0        /2OMB0ynKlyIenMJWI2Dy9IWT4c.jpg  ...
# 1       /gFZriCkpJYsApPZEF3jhxL4yLzG.jpg  ...
# 2       /2MaumbgBlW1NoPo3ZJO38A6v7OS.jpg  ...
# 3       /x4salpjB11umlUOltfNvSSrjSXm.jpg  ...
# 4       /aDBRtunw49UF4XmqfyNuD9nlYIu.jpg  ...
# ...                                  ...  ...
# 152806  /9Gk7q2f2ZNDvXvNtIaRbljt4IX5.jpg  ...
# 153631                               NaN  ...
# 155699                               NaN  ...
# 158034  /1TMS8iDozeoCIZmpZIlfShJSSzG.jpg  ...
# 158797                               NaN  ...
#
#                                  tagline  \
# 0                       Winter Is Coming
# 1                   The perfect robbery.
# 2          Every ending has a beginning.
# 3       Fight the dead. Fear the living.
# 4                   It's good to be bad.
# ...                                  ...
# 152806                               NaN
# 153631                               NaN
# 155699                               NaN
# 158034                               NaN
# 158797                               NaN
#
#                                              genres  \
# 0       Sci-Fi & Fantasy, Drama, Action & Adventure
# 1                                      Crime, Drama
# 2                  Drama, Sci-Fi & Fantasy, Mystery
# 3       Action & Adventure, Drama, Sci-Fi & Fantasy
# 4                           Crime, Sci-Fi & Fantasy
# ...                                             ...
# 152806                                        Drama
# 153631                                          NaN
# 155699                                  Documentary
# 158034                                          NaN
# 158797                                          NaN
#
#                        created_by  languages           networks  \
# 0       David Benioff, D.B. Weiss         en                HBO
# 1                       Álex Pina         es  Netflix, Antena 3
# 2        Matt Duffer, Ross Duffer         en            Netflix
# 3                  Frank Darabont         en                AMC
# 4                     Tom Kapinos         en       FOX, Netflix
# ...                           ...        ...                ...
# 152806                        NaN         av           Jawwy TV
# 153631                        NaN         km                NaN
# 155699                        NaN     en, gd                NaN
# 158034      Luis Felipe Salamanca         la                NaN
# 158797                        NaN        NaN                NaN
#
#         origin_country spoken_languages  \
# 0                   US          English
# 1                   ES          Español
# 2                   US          English
# 3                   US          English
# 4                   US          English
# ...                ...              ...
# 152806              SA              NaN
# 153631             NaN              NaN
# 155699              GB          English
# 158034              CO            Latin
# 158797             NaN              NaN
#
#                                      production_companies  \
# 0       Revolution Sun Studios, Television 360, Genera...
# 1                                         Vancouver Media
# 2       21 Laps Entertainment, Monkey Massacre Product...
# 3       AMC Studios, Circle of Confusion, Valhalla Mot...
# 4       Warner Bros. Television, DC Entertainment, Jer...
# ...                                                   ...
# 152806                                           Jawwy TV
# 153631                                                NaN
# 155699                                                NaN
# 158034                                            Teleset
# 158797                                                NaN
#
#                             production_countries episode_run_time
# 0       United Kingdom, United States of America                0
# 1                                          Spain               70
# 2                       United States of America                0
# 3                       United States of America               42
# 4                       United States of America               45
# ...                                          ...              ...
# 152806                              Saudi Arabia                0
# 153631                                       NaN                0
# 155699                            United Kingdom                0
# 158034                                  Colombia               45
# 158797                                       NaN                0
#
# [439 rows x 29 columns]

# %%
unique = df[['original_language', 'languages']].drop_duplicates()

# %%
unique
# Out:
#        original_language   languages
# 0                     en          en
# 1                     es          es
# 6                     ko  en, ko, ur
# 7                     en  en, de, es
# 24                    ja          ja
# ...                  ...         ...
# 158612                fr          ko
# 158797                so         NaN
# 158843                fi          sv
# 158989                da  da, en, uk
# 158996                ms      ms, en
#
# [1701 rows x 2 columns]

# %%
df2=unique.groupby('original_language').agg({'languages': 'first'})

# %%
df2
# Out:
#                   languages
# original_language
# aa                     None
# ab                       ja
# af                       af
# am                       am
# ar                       ar
# ...                     ...
# vi                       vi
# xx                       xx
# za                       zh
# zh                       zh
# zu                       en
#
# [106 rows x 1 columns]
